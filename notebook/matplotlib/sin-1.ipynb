# %%
import math

# %%
import matplotlib.pyplot as plt

# %%
t = range(100)

# %%
x = [(2 * math.pi * ti)/ len(t) for ti in t]

# %%
y = [math.sin(v) for v in x]

# %%
plt.plot(x, y)

# %%
plt.show()
